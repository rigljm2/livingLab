# %%
import pandas as pd

# df = pd.read_excel("엑셀 파일 경로", sheet_name = 불러올 시트의 인덱스)
df = pd.read_excel("CleanNetAddress.xlsx", sheet_name=1)

# 시작점과 10개의 노드의 위도 경도를 설정
start_point = (36.420971, 127.423380)  # (유)오성알씨의 위도 경도.
nodes = []

# 행 단위로 데이터 처리
for index, row in df.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    nodes.append((latitude, longitude))

# %%
import folium

# 지도 객체 생성
m = folium.Map(location=start_point, zoom_start=15)

# 시작점 마커 추가
folium.Marker(start_point, popup="Start Point", icon=folium.Icon(color='red')).add_to(m)

# 노드 마커 추가
for i, node in enumerate(nodes):
    folium.Marker(node, popup=f"Node {i+1}", icon=folium.Icon(color='blue')).add_to(m)

# 0 -> 2 -> 4 -> 7 경로 그리기 (빨간색)
path1_coords = [nodes[0], nodes[2], nodes[4], nodes[7]]
folium.PolyLine(path1_coords, color="red", weight=2.5, opacity=1).add_to(m)

# 4 -> 6 -> 8 -> 0 경로 그리기 (파란색)
path2_coords = [nodes[4], nodes[6], nodes[8], nodes[0]]
folium.PolyLine(path2_coords, color="blue", weight=2.5, opacity=1).add_to(m)

# 지도 파일로 저장
m.save("map_with_nodes.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1650d36a1ba4b602aa1178d55099df84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1650d36a1ba4b602aa1178d55099df84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1650d36a1ba4b602aa1178d55099df84 = L.map(
#                 &quot;map_1650d36a1ba4b602aa1178d55099df84&quot;,
#                 {
#                     center: [36.420971, 127.42338],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4015cad21742cc2ed4fd72b7d9755b58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4015cad21742cc2ed4fd72b7d9755b58.addTo(map_1650d36a1ba4b602aa1178d55099df84);
#
#
#             var marker_5e98786ae36e4fcff5508b2dd2621350 = L.marker(
#                 [36.420971, 127.42338],
#                 {}
#             ).addTo(map_1650d36a1ba4b602aa1178d55099df84);
#
#
#             var icon_f25e9f58d02c2292b5c3060bf7774222 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e98786ae36e4fcff5508b2dd2621350.setIcon(icon_f25e9f58d02c2292b5c3060bf7774222);
#
#
#         var popup_b21cb8c5e02c2cbab4eb57bb4ac222c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce28399d2edd67c0bc0c62bd742c0ef6 = $(`&lt;div id=&quot;html_ce28399d2edd67c0bc0c62bd742c0ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start Point&lt;/div&gt;`)[0];
#                 popup_b21cb8c5e02c2cbab4eb57bb4ac222c0.setContent(html_ce28399d2edd67c0bc0c62bd742c0ef6);
#
#
#
#         marker_5e98786ae36e4fcff5508b2dd2621350.bindPopup(popup_b21cb8c5e02c2cbab4eb57bb4ac222c0)
#         ;
#
#
#
#
#             var marker_fe1e6ab3dc249a64ea42410e48dd47bd = L.marker(
#                 [36.3317391043375, 127.344830399223],
#                 {}
#             ).addTo(map_1650d36a1ba4b602aa1178d55099df84);
#
#
#             var icon_270d4791d2b3ef40dd80f71f05a20ec8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe1e6ab3dc249a64ea42410e48dd47bd.setIcon(icon_270d4791d2b3ef40dd80f71f05a20ec8);
#
#
#         var popup_4cd226ea0dffe30c2484d868017b26f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_257c4b166031dd61230059fa134b86dd = $(`&lt;div id=&quot;html_257c4b166031dd61230059fa134b86dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Node 1&lt;/div&gt;`)[0];
#                 popup_4cd226ea0dffe30c2484d868017b26f3.setContent(html_257c4b166031dd61230059fa134b86dd);
#
#
#
#         marker_fe1e6ab3dc249a64ea42410e48dd47bd.bindPopup(popup_4cd226ea0dffe30c2484d868017b26f3)
#         ;
#
#
#
#
#             var marker_b7706c66f7d5e15e95cc0fdbad29f7a4 = L.marker(
#                 [36.3316653798501, 127.341095936769],
#                 {}
#             ).addTo(map_1650d36a1ba4b602aa1178d55099df84);
#
#
#             var icon_864ed2bdfca187cb40cb7d963a732309 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b7706c66f7d5e15e95cc0fdbad29f7a4.setIcon(icon_864ed2bdfca187cb40cb7d963a732309);
#
#
#         var popup_3131cfee803b2850ac42aa2d1b0ff4bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_925a5616eec9881236ea685c9e0d2653 = $(`&lt;div id=&quot;html_925a5616eec9881236ea685c9e0d2653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Node 2&lt;/div&gt;`)[0];
#                 popup_3131cfee803b2850ac42aa2d1b0ff4bf.setContent(html_925a5616eec9881236ea685c9e0d2653);
#
#
#
#         marker_b7706c66f7d5e15e95cc0fdbad29f7a4.bindPopup(popup_3131cfee803b2850ac42aa2d1b0ff4bf)
#         ;
#
#
#
#
#             var marker_3c6e78e13cedc660bfd34d7093b78c08 = L.marker(
#                 [36.3309804675651, 127.341795622727],
#                 {}
#             ).addTo(map_1650d36a1ba4b602aa1178d55099df84);
#
#
#             var icon_fac5ece58868156f2517ea64e89c3d76 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;

# %%
import matplotlib.pyplot as plt

# 위도와 경도를 그대로 사용한 좌표 평면 그래프
plt.figure(figsize=(8, 6))

# 시작점과 모든 노드 플로팅 (동그라미로 표시)
plt.scatter(*start_point, color='red', label='Start Point', s=100, edgecolor='black', linewidth=2, marker='o')  
for i, node in enumerate(nodes):
    plt.scatter(*node, color='blue', label=f'Node {i+1}' if i == 0 else "", s=100, edgecolor='black', linewidth=2, marker='o')
    plt.text(node[0], node[1], f'Node {i+1}', fontsize=9, verticalalignment='bottom')

# 0 -> 2 -> 4 -> 7 순서로 빨간색 화살표 추가
path1 = [0, 2, 4, 7]
for i in range(len(path1) - 1):
    node_start = nodes[path1[i]]
    node_end = nodes[path1[i+1]]
    plt.annotate('', xy=node_end, xytext=node_start,
                 arrowprops=dict(color='red', arrowstyle='->', lw=2))

# 4 -> 6 -> 8 -> 0 순서로 파란색 화살표 추가
path2 = [4, 6, 8, 0]
for i in range(len(path2) - 1):
    node_start = nodes[path2[i]]
    node_end = nodes[path2[i+1]]
    plt.annotate('', xy=node_end, xytext=node_start,
                 arrowprops=dict(color='blue', arrowstyle='->', lw=2))

# 축 레이블 설정 (위도와 경도 그대로 사용)
plt.xlabel("Latitude")
plt.ylabel("Longitude")

# 지수 표기법 제거
plt.ticklabel_format(useOffset=False, style='plain')

# 범례 추가
plt.legend()

# 제목 추가
plt.title("Custom Paths with Arrows and Accurate Latitude/Longitude")

# 그래프 출력
plt.grid(True)
plt.show()
